# %% [markdown]
# ## RL

# %%
import numpy as np
import pandas as pd
import gym
from gym import spaces
import torch
import torch.nn as nn
import torch.optim as optim
import random
from collections import deque
import backtrader as bt
from typing import Optional, List
from trading.utils import *
from trading.traditional_strategies import *
from trading.trader import *

# %%
class TradingEnv(gym.Env):
    """
    Custom Trading Environment for Reinforcement Learning.
    """

    def __init__(self, data, initial_balance=1000000):
        super(TradingEnv, self).__init__()
        self.data = data
        self.initial_balance = initial_balance
        self.current_step = 0
        self.balance = initial_balance
        self.positions = 0  # Number of stocks held
        self.total_value = initial_balance
        self.max_steps = len(data)

        # Action space: 0 (Hold), 1 (Buy), 2 (Sell)
        self.action_space = spaces.Discrete(3)

        # Observation space: OHLCV + balance + positions
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(len(data.columns) + 2,), dtype=np.float32
        )

    def reset(self):
        self.current_step = 0
        self.balance = self.initial_balance
        self.positions = 0
        self.total_value = self.initial_balance
        return self._get_observation()

    def _get_observation(self):
        return np.concatenate(
            [self.data.iloc[self.current_step].values, [self.balance, self.positions]]
        )

    def step(self, action):
        current_price = self.data.iloc[self.current_step]["Close"]
        transaction_cost = 0.001  # Example: 0.1% transaction cost per trade

        if action == 1:  # Buy
            self.positions += 1
            self.balance -= current_price * (1 + transaction_cost)

        elif action == 2:  # Sell
            if self.positions > 0:
                self.positions -= 1
                self.balance += current_price * (1 - transaction_cost)

        self.current_step += 1
        done = self.current_step >= self.max_steps - 1

        # Update portfolio value
        self.total_value = self.balance + self.positions * current_price

        # Reward: Portfolio value change
        reward = self.total_value - self.initial_balance

        return self._get_observation(), reward, done, {}

    def render(self):
        print(f"Step: {self.current_step}, Balance: {self.balance}, Positions: {self.positions}, Total Value: {self.total_value}")

# %%
class DQN(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(input_dim, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, output_dim)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95  # Discount factor
        self.epsilon = 1.0  # Exploration rate
        self.epsilon_decay = 0.995
        self.epsilon_min = 0.01
        self.learning_rate = 0.001

        self.model = DQN(state_size, action_size).float()
        self.optimizer = optim.Adam(self.model.parameters(), lr=self.learning_rate)
        self.criterion = nn.MSELoss()

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        state = torch.tensor(state, dtype=torch.float32).unsqueeze(0)
        act_values = self.model(state)
        return torch.argmax(act_values).item()

    def replay(self, batch_size):
        if len(self.memory) < batch_size:
            return

        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                next_state = torch.tensor(next_state, dtype=torch.float32).unsqueeze(0)
                target = reward + self.gamma * torch.max(self.model(next_state)).item()

            state = torch.tensor(state, dtype=torch.float32).unsqueeze(0)
            target_f = self.model(state).detach().clone()
            target_f[0][action] = target

            output = self.model(state)
            loss = self.criterion(output, target_f)

            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %%
# Load stock data
data = pd.read_csv("data/us_stock/all_GOOG.csv")
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)

# Initialize trading environment
env = TradingEnv(data)
state_size = env.observation_space.shape[0]
action_size = env.action_space.n

# Initialize DQN agent
agent = DQNAgent(state_size, action_size)

# Train the agent
episodes = 100
batch_size = 32

for e in range(episodes):
    state = env.reset()
    total_reward = 0

    for time in range(env.max_steps):
        action = agent.act(state)
        next_state, reward, done, _ = env.step(action)
        agent.remember(state, action, reward, next_state, done)
        state = next_state
        total_reward += reward

        if done:
            print(f"Episode {e+1}/{episodes}, Total Reward: {total_reward}")
            break

    agent.replay(batch_size)

# Save the trained model
torch.save(agent.model.state_dict(), "dqn_model.pth")
# Out:
# Episode 1/200, Total Reward: 1408169.7291684193
# Episode 2/200, Total Reward: 2350906.9309006203
# Episode 3/200, Total Reward: 5027565.6547876075
# Episode 4/200, Total Reward: 2076453.5786546555
# Episode 5/200, Total Reward: 1930844.9631422646
# Episode 6/200, Total Reward: 896853.6480344462
# Episode 7/200, Total Reward: 2133491.6835321793
# Episode 8/200, Total Reward: 1176090.1683220868
# Episode 9/200, Total Reward: 2381552.5867545167
# Episode 10/200, Total Reward: 10169066.13056359
# Episode 11/200, Total Reward: 6085411.416798484
# Episode 12/200, Total Reward: 14515570.865258634
# Episode 145/200, Total Reward: 1604822.5555423712
# Episode 146/200, Total Reward: 6465300.353758902
# Episode 147/200, Total Reward: 28500753.11664774
# Episode 148/200, Total Reward: 260377.78819260956
# Episode 149/200, Total Reward: -8380.927768926485
# Episode 150/200, Total Reward: 1139561.0953238658
# Episode 151/200, Total Reward: 9141913.526365722
# Episode 152/200, Total Reward: 2592117.4943553335
# Episode 153/200, Total Reward: 1839172.9277924292
# Episode 154/200, Total Reward: 573543.364148823
# Episode 155/200, Total Reward: 830565.4065812865
# Episode 156/200, Total Reward: 49859740.57622587
# Episode 157/200, Total Reward: 65746379.34519794
# Episode 158/200, Total Reward: 62390328.50352212
# Episode 159/200, Total Reward: 1662414.344697582
# Episode 160/200, Total Reward: 99430516.52685788
# Episode 161/200, Total Reward: 95416911.73558791
# Episode 162/200, Total Reward: 98165962.33723912
# Episode 163/200, Total Reward: 988818.4365320213
# Episode 164/200, Total Reward: 100873773.26911049
# Episode 165/200, Total Reward: 91936658.42071566
# Episode 166/200, Total Reward: 1185307.0960656132
# Episode 167/200, Total Reward: 96855069.62554118
# Episode 168/200, Total Reward: 94359562.97731857
# Episode 169/200, Total Reward: 99516797.7920213
# Episode 170/200, Total Reward: 104731864.24868803
# Episode 171/200, Total Reward: 98619802.00887318
# Episode 172/200, Total Reward: -33322.61020372994
# Episode 173/200, Total Reward: -66903.44523270405
# Episode 174/200, Total Reward: -37764.546149317874
# Episode 175/200, Total Reward: 100384922.10529362
# Episode 176/200, Total Reward: 101292187.37937501
# Episode 177/200, Total Reward: 106348789.38238153
# Episode 178/200, Total Reward: 89952018.20648348
# Episode 179/200, Total Reward: 104138591.4771468
# Episode 180/200, Total Reward: 2771400.4807041176
# Episode 181/200, Total Reward: 101970315.5453563
# Episode 182/200, Total Reward: 105280569.53204733
# Episode 183/200, Total Reward: 549152.0836020515
# Episode 184/200, Total Reward: -5300.58827180462
# Episode 185/200, Total Reward: 13149.366954243858
# Episode 186/200, Total Reward: -29233.608382840874
# Episode 187/200, Total Reward: -117359.71618493111
# Episode 188/200, Total Reward: -67201.37388179323
# Episode 189/200, Total Reward: -21180.737786154612
# Episode 190/200, Total Reward: 11018.314954824862
# Episode 191/200, Total Reward: 106517478.92665507
# Episode 192/200, Total Reward: 106337258.42691119
# Episode 193/200, Total Reward: 108652001.90749936
# Episode 194/200, Total Reward: 111166536.54541242
# Episode 195/200, Total Reward: 107792361.47646433
# Episode 196/200, Total Reward: 2418246.874213614
# Episode 197/200, Total Reward: 69966367.763641
# Episode 198/200, Total Reward: 100203631.94702092
# Episode 199/200, Total Reward: 99804646.11427493
# Episode 200/200, Total Reward: 98407222.09148157

# %%
class DQNStrategy(BaseStrategy):
    params = (("model", None),)

    def __init__(self):
        self.model = self.params.model
        self.dataclose = self.data.close

    def next(self):
        state = np.array([
            self.data.open[0],
            self.data.high[0],
            self.data.low[0],
            self.data.close[0],
            self.data.volume[0],
        ])

        # Get the action from the DQN model
        action = self.model.act(state)

        # Execute the action
        if action == 1:  # Buy
            if not self.position:
                self.buy(size=100)
        elif action == 2:  # Sell
            if self.position:
                self.sell(size=100)

# Load the trained model
agent = DQNAgent(state_size, action_size)
agent.model.load_state_dict(torch.load("dqn_model.pth"))

# Run the backtest
trader = AITrader(start_date="2024-01-01", end_date="2024-10-01")
trader.add_strategy(DQNStrategy, {"model": agent})
trader.run(1, stock_ticker="TSLA")
# Out:
# --- AITrader initialization ---
# Strategy 'DQNStrategy' added with model and parameters: {'model': <__main__.DQNAgent object at 0x16d77db90>}
# Data loaded.
# Starting Value: 1000000
# Sizer set to 95%.
# Analyzers added.
#
# --- Backtesting ---
# 2024-01-03, [BUY] EXECUTED at Price: 244.98     | Total Cost: 24498.00   | Commision: 34.91
# 2024-01-08, [SELL] EXECUTED at Price: 236.14     | Total Cost: 24498.00   | Commision: 33.65
# 2024-01-08, [OPERATION PROFIT] Gross: -884.00    | Net: -952.56
# 2024-01-10, [BUY] EXECUTED at Price: 235.10     | Total Cost: 23510.00   | Commision: 33.50
# 2024-01-16, [SELL] EXECUTED at Price: 215.10     | Total Cost: 23510.00   | Commision: 30.65
# 2024-01-16, [OPERATION PROFIT] Gross: -2000.00   | Net: -2064.15
# 2024-01-18, [BUY] EXECUTED at Price: 216.88     | Total Cost: 21688.00   | Commision: 30.91
# 2024-01-22, [SELL] EXECUTED at Price: 212.26     | Total Cost: 21688.00   | Commision: 30.25
# 2024-01-22, [OPERATION PROFIT] Gross: -462.00    | Net: -523.15
# 2024-01-24, [BUY] EXECUTED at Price: 211.88     | Total Cost: 21188.00   | Commision: 30.19
# 2024-01-25, [SELL] EXECUTED at Price: 189.70     | Total Cost: 21188.00   | Commision: 27.03
# 2024-01-25, [OPERATION PROFIT] Gross: -2218.00   | Net: -2275.23
# 2024-02-01, [BUY] EXECUTED at Price: 188.50     | Total Cost: 18850.00   | Commision: 26.86
# 2024-02-02, [SELL] EXECUTED at Price: 185.04     | Total Cost: 18850.00   | Commision: 26.37
# 2024-02-02, [OPERATION PROFIT] Gross: -346.00    | Net: -399.23
# 2024-02-05, [BUY] EXECUTED at Price: 184.26     | Total Cost: 18426.00   | Commision: 26.26
# 2024-02-07, [SELL] EXECUTED at Price: 188.18     | Total Cost: 18426.00   | Commision: 26.82
# 2024-02-07, [OPERATION PROFIT] Gross: 392.00     | Net: 338.93
# 2024-02-08, [BUY] EXECUTED at Price: 189.00     | Total Cost: 18900.00   | Commision: 26.93
# 2024-02-12, [SELL] EXECUTED at Price: 192.11     | Total Cost: 18900.00   | Commision: 27.38
# 2024-02-12, [OPERATION PROFIT] Gross: 311.00     | Net: 256.69
# 2024-02-13, [BUY] EXECUTED at Price: 183.99     | Total Cost: 18399.00   | Commision: 26.22
# 2024-02-16, [SELL] EXECUTED at Price: 202.06     | Total Cost: 18399.00   | Commision: 28.79
# 2024-02-16, [OPERATION PROFIT] Gross: 1807.00    | Net: 1751.99
# 2024-02-21, [BUY] EXECUTED at Price: 193.36     | Total Cost: 19336.00   | Commision: 27.55
# 2024-02-26, [SELL] EXECUTED at Price: 192.29     | Total Cost: 19336.00   | Commision: 27.40
# 2024-02-26, [OPERATION PROFIT] Gross: -107.00    | Net: -161.96
# 2024-02-27, [BUY] EXECUTED at Price: 204.04     | Total Cost: 20404.00   | Commision: 29.08
# 2024-06-14, [SELL] EXECUTED at Price: 185.80     | Total Cost: 18839.00   | Commision: 26.48
# 2024-06-14, [OPERATION PROFIT] Gross: -259.00    | Net: -312.32
# 2024-06-21, [BUY] EXECUTED at Price: 182.30     | Total Cost: 18230.00   | Commision: 25.98
# 2024-06-24, [SELL] EXECUTED at Price: 184.97     | Total Cost: 18230.00   | Commision: 26.36
# 2024-06-24, [OPERATION PROFIT] Gross: 267.00     | Net: 214.66
# 2024-07-05, [BUY] EXECUTED at Price: 249.81     | Total Cost: 24981.00   | Commision: 35.60
# 2024-07-19, [SELL] EXECUTED at Price: 247.79     | Total Cost: 24981.00   | Commision: 35.31
# 2024-07-19, [OPERATION PROFIT] Gross: -202.00    | Net: -272.91
# 2024-07-23, [BUY] EXECUTED at Price: 253.60     | Total Cost: 25360.00   | Commision: 36.14
# 2024-07-24, [SELL] EXECUTED at Price: 225.42     | Total Cost: 25360.00   | Commision: 32.12
# 2024-07-24, [OPERATION PROFIT] Gross: -2818.00   | Net: -2886.26
# 2024-07-25, [BUY] EXECUTED at Price: 216.80     | Total Cost: 21680.00   | Commision: 30.89
# 2024-08-01, [SELL] EXECUTED at Price: 227.69     | Total Cost: 21680.00   | Commision: 32.45
# 2024-08-01, [OPERATION PROFIT] Gross: 1089.00    | Net: 1025.66
# 2024-08-02, [BUY] EXECUTED at Price: 214.88     | Total Cost: 21488.00   | Commision: 30.62
# 2024-08-07, [SELL] EXECUTED at Price: 200.77     | Total Cost: 21488.00   | Commision: 28.61
# 2024-08-07, [OPERATION PROFIT] Gross: -1411.00   | Net: -1470.23
# 2024-08-12, [BUY] EXECUTED at Price: 199.02     | Total Cost: 19902.00   | Commision: 28.36
# 2024-08-13, [SELL] EXECUTED at Price: 198.47     | Total Cost: 19902.00   | Commision: 28.28
# 2024-08-13, [OPERATION PROFIT] Gross: -55.00     | Net: -111.64
# 2024-08-15, [BUY] EXECUTED at Price: 205.02     | Total Cost: 20502.00   | Commision: 29.22
# 2024-08-19, [SELL] EXECUTED at Price: 217.07     | Total Cost: 20502.00   | Commision: 30.93
# 2024-08-19, [OPERATION PROFIT] Gross: 1205.00    | Net: 1144.85
# 2024-08-21, [BUY] EXECUTED at Price: 222.67     | Total Cost: 22267.00   | Commision: 31.73
# 2024-08-28, [SELL] EXECUTED at Price: 209.72     | Total Cost: 22267.00   | Commision: 29.89
# 2024-08-28, [OPERATION PROFIT] Gross: -1295.00   | Net: -1356.62
# 2024-09-04, [BUY] EXECUTED at Price: 210.59     | Total Cost: 21059.00   | Commision: 30.01
# 2024-09-18, [SELL] EXECUTED at Price: 230.09     | Total Cost: 21059.00   | Commision: 32.79
# 2024-09-18, [OPERATION PROFIT] Gross: 1950.00    | Net: 1887.20
#
# ---Result Analysis---
# Ending Value: 992809
# Total Returns (%): -0.72
# Annualized Returns (%): -0.96
# Max Drawdown (%): 0.91
#
# --- Strategy Evaluation ---
# Total Returns are negative, indicating a loss.
# Max Drawdown is within acceptable limits (< 20%), suggesting a stable strategy.
# {'Ending Value': 992809,
#  'Total Returns (%)': -0.72,
#  'Annualized Returns (%)': -0.96,
#  'Max Drawdown (%)': 0.91}
