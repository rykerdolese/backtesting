# %% [markdown]
# ## RL

# %%
import numpy as np
import pandas as pd
import gym
from gym import spaces
import torch
import torch.nn as nn
import torch.optim as optim
import random
from collections import deque
import backtrader as bt
from typing import Optional, List
from trading.utils import *
from trading.traditional_strategies import *
from trading.trader import *

# %%
class TradingEnv(gym.Env):
    """
    Custom Trading Environment for Reinforcement Learning.
    """

    def __init__(self, data, initial_balance=1000000):
        super(TradingEnv, self).__init__()
        self.data = data
        self.initial_balance = initial_balance
        self.current_step = 0
        self.balance = initial_balance
        self.positions = 0  # Number of stocks held
        self.total_value = initial_balance
        self.max_steps = len(data)

        # Action space: 0 (Hold), 1 (Buy), 2 (Sell)
        self.action_space = spaces.Discrete(3)

        # Observation space: OHLCV + balance + positions
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(len(data.columns) + 2,), dtype=np.float32
        )

    def reset(self):
        self.current_step = 0
        self.balance = self.initial_balance
        self.positions = 0
        self.total_value = self.initial_balance
        return self._get_observation()

    def _get_observation(self):
        return np.concatenate(
            [self.data.iloc[self.current_step].values, [self.balance, self.positions]]
        )

    def step(self, action):
        current_price = self.data.iloc[self.current_step]["Close"]
        transaction_cost = 0.001  # Example: 0.1% transaction cost per trade

        if action == 1:  # Buy
            self.positions += 1
            self.balance -= current_price * (1 + transaction_cost)

        elif action == 2:  # Sell
            if self.positions > 0:
                self.positions -= 1
                self.balance += current_price * (1 - transaction_cost)

        self.current_step += 1
        done = self.current_step >= self.max_steps - 1

        # Update portfolio value
        self.total_value = self.balance + self.positions * current_price

        # Reward: Portfolio value change
        reward = self.total_value - self.initial_balance

        return self._get_observation(), reward, done, {}

    def render(self):
        print(f"Step: {self.current_step}, Balance: {self.balance}, Positions: {self.positions}, Total Value: {self.total_value}")

# %%
class DQN(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(input_dim, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, 128)
        self.fc4 = nn.Linear(128, output_dim)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.relu(self.fc3(x))
        return self.fc4(x)

class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95  # Discount factor
        self.epsilon = 1.0  # Exploration rate
        self.epsilon_decay = 0.995
        self.epsilon_min = 0.01
        self.learning_rate = 0.001

        self.model = DQN(state_size, action_size).float()
        self.optimizer = optim.Adam(self.model.parameters(), lr=self.learning_rate)
        self.criterion = nn.MSELoss()

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        state = torch.tensor(state, dtype=torch.float32).unsqueeze(0)
        act_values = self.model(state)
        return torch.argmax(act_values).item()

    def replay(self, batch_size):
        if len(self.memory) < batch_size:
            return

        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                next_state = torch.tensor(next_state, dtype=torch.float32).unsqueeze(0)
                target = reward + self.gamma * torch.max(self.model(next_state)).item()

            state = torch.tensor(state, dtype=torch.float32).unsqueeze(0)
            target_f = self.model(state).detach().clone()
            target_f[0][action] = target

            output = self.model(state)
            loss = self.criterion(output, target_f)

            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %%
# Load stock data
data = pd.read_csv("data/us_stock/all_GOOG.csv")
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)

# Initialize trading environment
env = TradingEnv(data)
state_size = env.observation_space.shape[0]
action_size = env.action_space.n

# Initialize DQN agent
agent = DQNAgent(state_size, action_size)

# Train the agent
episodes = 100
batch_size = 32

for e in range(episodes):
    state = env.reset()
    total_reward = 0

    for time in range(env.max_steps):
        action = agent.act(state)
        next_state, reward, done, _ = env.step(action)
        agent.remember(state, action, reward, next_state, done)
        state = next_state
        total_reward += reward

        if done:
            print(f"Episode {e+1}/{episodes}, Total Reward: {total_reward}")
            break

    agent.replay(batch_size)

# Save the trained model
torch.save(agent.model.state_dict(), "dqn_model.pth")
# Out:
# Episode 1/100, Total Reward: 1989842.9487845725
# Episode 2/100, Total Reward: 1741978.1544580855
# Episode 3/100, Total Reward: 2903389.9422170212
# Episode 4/100, Total Reward: 5226827.298101802
# Episode 65/100, Total Reward: 3196349.9685599124
# Episode 66/100, Total Reward: 464699.61223011534
# Episode 67/100, Total Reward: 43693347.32900473
# Episode 68/100, Total Reward: 47922009.96207049
# Episode 69/100, Total Reward: 51328753.88997575
# Episode 70/100, Total Reward: 52545572.52814578
# Episode 71/100, Total Reward: 1328495.9554580827
# Episode 72/100, Total Reward: -36151.79767192807
# Episode 73/100, Total Reward: 2248570.452989906
# Episode 74/100, Total Reward: 50060566.157621324
# Episode 75/100, Total Reward: 2094344.578140282
# Episode 76/100, Total Reward: 76448.26003483008
# Episode 77/100, Total Reward: 317552.20420606784
# Episode 78/100, Total Reward: 22492.899791007396
# Episode 79/100, Total Reward: 139478.81250898668
# Episode 80/100, Total Reward: 3279257.9197342917
# Episode 81/100, Total Reward: 1417270.071164969
# Episode 82/100, Total Reward: 59216348.281752855
# Episode 83/100, Total Reward: 60876462.565001115
# Episode 84/100, Total Reward: 19112912.411298573
# Episode 85/100, Total Reward: 57269089.49262845
# Episode 86/100, Total Reward: -28973.585385066108
# Episode 87/100, Total Reward: 63673433.69379078
# Episode 88/100, Total Reward: 62124235.57783151
# Episode 89/100, Total Reward: 741407.8228325844
# Episode 90/100, Total Reward: 64044005.02741463
# Episode 91/100, Total Reward: 62901299.495498136
# Episode 92/100, Total Reward: 1875175.1011820012
# Episode 93/100, Total Reward: 60601996.78390995
# Episode 94/100, Total Reward: 60052348.26584841
# Episode 95/100, Total Reward: 5725002.856225273
# Episode 96/100, Total Reward: 9305198.099094927
# Episode 97/100, Total Reward: -27401.2722444518
# Episode 98/100, Total Reward: 67797460.34402068
# Episode 99/100, Total Reward: 66238479.95365813
# Episode 100/100, Total Reward: 63338657.43555096

# %%
class DQNStrategy(BaseStrategy):
    params = (("model", None),)

    def __init__(self):
        self.model = self.params.model
        self.dataclose = self.data.close

    def next(self):
        state = np.array([
            self.data.open[0],
            self.data.high[0],
            self.data.low[0],
            self.data.close[0],
            self.data.volume[0],
        ])

        # Get the action from the DQN model
        action = self.model.act(state)

        # Execute the action
        if action == 1:  # Buy
            if not self.position:
                self.buy(size=100)
        elif action == 2:  # Sell
            if self.position:
                self.sell(size=100)

# Load the trained model
agent = DQNAgent(state_size, action_size)
agent.model.load_state_dict(torch.load("dqn_model.pth"))

# Run the backtest
trader = AITrader(start_date="2024-01-01", end_date="2024-10-01")
trader.add_strategy(DQNStrategy, {"model": agent})
trader.run(1, stock_ticker="TSLA")
# Out:
# --- AITrader initialization ---
# Strategy 'DQNStrategy' added with model and parameters: {'model': <__main__.DQNAgent object at 0x16cac1e10>}
# Data loaded.
# Starting Value: 1000000
# Sizer set to 95%.
# Analyzers added.
#
# --- Backtesting ---
# 2024-01-03, [BUY] EXECUTED at Price: 244.98     | Total Cost: 24498.00   | Commision: 34.91
# 2024-03-26, [SELL] EXECUTED at Price: 178.58     | Total Cost: 16876.00   | Commision: 25.45
# 2024-03-26, [OPERATION PROFIT] Gross: 982.00     | Net: 932.50
# 2024-03-27, [BUY] EXECUTED at Price: 181.41     | Total Cost: 18141.00   | Commision: 25.85
# 2024-04-05, [SELL] EXECUTED at Price: 169.08     | Total Cost: 18141.00   | Commision: 24.09
# 2024-04-05, [OPERATION PROFIT] Gross: -1233.00   | Net: -1282.95
# 2024-04-22, [BUY] EXECUTED at Price: 140.56     | Total Cost: 14056.00   | Commision: 20.03
# 2024-04-23, [SELL] EXECUTED at Price: 143.33     | Total Cost: 14056.00   | Commision: 20.42
# 2024-04-23, [OPERATION PROFIT] Gross: 277.00     | Net: 236.55
# 2024-05-01, [BUY] EXECUTED at Price: 182.00     | Total Cost: 18200.00   | Commision: 25.94
# 2024-05-07, [SELL] EXECUTED at Price: 182.40     | Total Cost: 18200.00   | Commision: 25.99
# 2024-05-07, [OPERATION PROFIT] Gross: 40.00      | Net: -11.93
# 2024-05-08, [BUY] EXECUTED at Price: 171.59     | Total Cost: 17159.00   | Commision: 24.45
# 2024-05-10, [SELL] EXECUTED at Price: 173.05     | Total Cost: 17159.00   | Commision: 24.66
# 2024-05-10, [OPERATION PROFIT] Gross: 146.00     | Net: 96.89
# 2024-05-13, [BUY] EXECUTED at Price: 170.00     | Total Cost: 17000.00   | Commision: 24.23
# 2024-05-15, [SELL] EXECUTED at Price: 179.90     | Total Cost: 17000.00   | Commision: 25.64
# 2024-05-15, [OPERATION PROFIT] Gross: 990.00     | Net: 940.14
# 2024-05-23, [BUY] EXECUTED at Price: 181.80     | Total Cost: 18180.00   | Commision: 25.91
# 2024-06-04, [SELL] EXECUTED at Price: 174.78     | Total Cost: 18180.00   | Commision: 24.91
# 2024-06-04, [OPERATION PROFIT] Gross: -702.00    | Net: -752.81
# 2024-06-10, [BUY] EXECUTED at Price: 176.06     | Total Cost: 17606.00   | Commision: 25.09
# 2024-06-13, [SELL] EXECUTED at Price: 188.39     | Total Cost: 17606.00   | Commision: 26.85
# 2024-06-13, [OPERATION PROFIT] Gross: 1233.00    | Net: 1181.07
# 2024-07-03, [BUY] EXECUTED at Price: 234.56     | Total Cost: 23456.00   | Commision: 33.42
# 2024-07-05, [SELL] EXECUTED at Price: 249.81     | Total Cost: 23456.00   | Commision: 35.60
# 2024-07-05, [OPERATION PROFIT] Gross: 1525.00    | Net: 1455.98
# 2024-07-12, [BUY] EXECUTED at Price: 235.80     | Total Cost: 23580.00   | Commision: 33.60
# 2024-07-18, [SELL] EXECUTED at Price: 251.09     | Total Cost: 23580.00   | Commision: 35.78
# 2024-07-18, [OPERATION PROFIT] Gross: 1529.00    | Net: 1459.62
# 2024-07-23, [BUY] EXECUTED at Price: 253.60     | Total Cost: 25360.00   | Commision: 36.14
# 2024-07-26, [SELL] EXECUTED at Price: 221.19     | Total Cost: 25360.00   | Commision: 31.52
# 2024-07-26, [OPERATION PROFIT] Gross: -3241.00   | Net: -3308.66
# 2024-07-29, [BUY] EXECUTED at Price: 224.90     | Total Cost: 22490.00   | Commision: 32.05
# 2024-07-31, [SELL] EXECUTED at Price: 227.90     | Total Cost: 22490.00   | Commision: 32.48
# 2024-07-31, [OPERATION PROFIT] Gross: 300.00     | Net: 235.48
# 2024-08-06, [BUY] EXECUTED at Price: 200.75     | Total Cost: 20075.00   | Commision: 28.61
# 2024-08-09, [SELL] EXECUTED at Price: 197.05     | Total Cost: 20075.00   | Commision: 28.08
# 2024-08-09, [OPERATION PROFIT] Gross: -370.00    | Net: -426.69
# 2024-08-14, [BUY] EXECUTED at Price: 207.39     | Total Cost: 20739.00   | Commision: 29.55
# 2024-08-16, [SELL] EXECUTED at Price: 211.15     | Total Cost: 20739.00   | Commision: 30.09
# 2024-08-16, [OPERATION PROFIT] Gross: 376.00     | Net: 316.36
# 2024-08-20, [BUY] EXECUTED at Price: 224.88     | Total Cost: 22488.00   | Commision: 32.05
# 2024-08-26, [SELL] EXECUTED at Price: 218.75     | Total Cost: 22488.00   | Commision: 31.17
# 2024-08-26, [OPERATION PROFIT] Gross: -613.00    | Net: -676.22
# 2024-08-27, [BUY] EXECUTED at Price: 213.25     | Total Cost: 21325.00   | Commision: 30.39
# 2024-09-03, [SELL] EXECUTED at Price: 215.26     | Total Cost: 21325.00   | Commision: 30.67
# 2024-09-03, [OPERATION PROFIT] Gross: 201.00     | Net: 139.94
# 2024-09-05, [BUY] EXECUTED at Price: 223.49     | Total Cost: 22349.00   | Commision: 31.85
# 2024-09-11, [SELL] EXECUTED at Price: 224.55     | Total Cost: 22349.00   | Commision: 32.00
# 2024-09-11, [OPERATION PROFIT] Gross: 106.00     | Net: 42.15
# 2024-09-12, [BUY] EXECUTED at Price: 224.66     | Total Cost: 22466.00   | Commision: 32.01
# 2024-09-24, [SELL] EXECUTED at Price: 254.08     | Total Cost: 22466.00   | Commision: 36.21
# 2024-09-24, [OPERATION PROFIT] Gross: 2942.00    | Net: 2873.78
# 2024-09-30, [BUY] EXECUTED at Price: 259.04     | Total Cost: 25904.00   | Commision: 36.91
# 2024-10-01, [SELL] EXECUTED at Price: 262.67     | Total Cost: 25904.00   | Commision: 37.43
# 2024-10-01, [OPERATION PROFIT] Gross: 363.00     | Net: 288.66
#
# ---Result Analysis---
# Ending Value: 994387
# Total Returns (%): -0.56
# Annualized Returns (%): -0.75
# Max Drawdown (%): 1.01
#
# --- Strategy Evaluation ---
# Total Returns are negative, indicating a loss.
# Max Drawdown is within acceptable limits (< 20%), suggesting a stable strategy.
# {'Ending Value': 994387,
#  'Total Returns (%)': -0.56,
#  'Annualized Returns (%)': -0.75,
#  'Max Drawdown (%)': 1.01}
